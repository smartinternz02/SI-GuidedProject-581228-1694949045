# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium
# 0    18.8     7.332    5.640          18.048       15.040       784.55  \
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.scatter(df.speeding,df.alcohol)

# %%
plt.scatter(df.speeding,df.alcohol)
plt.grid()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head(5)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium
# 0   18.8     7.332    5.640          18.048       15.040       784.55  \
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.scatterplot(x="ins_premium",y="ins_losses",data=df)
# Out:
# <Axes: xlabel='ins_premium', ylabel='ins_losses'>

# %%
sns.scatterplot(x="not_distracted",y="no_previous",data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='no_previous'>

# %%
sns.scatterplot(x="speeding",y="not_distracted",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='not_distracted'>

# %%
sns.lineplot(x="speeding",y="not_distracted",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='not_distracted'>

# %%
sns.distplot(df["speeding"])
# Out:
# C:\Users\ayanp\AppData\Local\Temp\ipykernel_4696\2127910581.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["speeding"])
# <Axes: xlabel='speeding', ylabel='Density'>

# %%
sns.displot(df["total"])
# Out:
# C:\Users\ayanp\AppData\Roaming\Python\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="speeding",y="alcohol",data=df,hue="no_previous")
# Out:
# C:\Users\ayanp\AppData\Roaming\Python\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="speeding",y="alcohol",data=df,hue="total")
# Out:
# C:\Users\ayanp\AppData\Roaming\Python\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(data=df,x="speeding",y="alcohol",)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
sns.countplot(x="speeding",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='count'>

# %%
sns.jointplot(x="alcohol",y="no_previous",data=df)

# %%
sns.boxplot(x="total",y="speeding",data=df)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %%
df.drop("abbrev",axis=1)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium
# 0    18.8     7.332    5.640          18.048       15.040       784.55  \
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium
# 0    18.8     7.332    5.640          18.048       15.040       784.55  \
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
corr=df.drop("abbrev",axis=1)
corr
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium
# 0    18.8     7.332    5.640          18.048       15.040       784.55  \
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
corr=corr.corr()
corr
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous
# total           1.000000  0.611548  0.852613        0.827560     0.956179  \
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(corr,annot=True,cmap="viridis")
# Out:
# <Axes: >
